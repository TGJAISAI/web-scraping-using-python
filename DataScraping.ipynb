# %% [markdown]
# <a href="https://colab.research.google.com/github/TGJAISAI/web-scraping-using-python/blob/main/DataScraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install beautifulsoup4
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install bs4
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install requests
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import requests
from bs4 import BeautifulSoup

# %%
ipohoneReviews = []
page = int(input("enter the page number:"))
if page <13:
    for i in range(1,int(page)+1):
        URL = 'https://www.flipkart.com/apple-iphone-13-pro-max-graphite-512-gb/product-reviews/itmbe5170f10a29f?pid=MOBG6VF5MNKYGQMA&lid=LSTMOBG6VF5MNKYGQMA3Q2IN7&marketplace=FLIPKART&page='+str(i)
        req = requests.get(URL)
        soup = BeautifulSoup(req.text, 'html.parser')
        Reviews = soup.find_all("div",{"class":"row"})
        print('Reviews in page'+str(i))
        print(len(Reviews))
        for i in Reviews:
            ipohoneReviews.append(i.text)
else:
    print("The max pages are only 12 kindly enter the number below 12")
# Out:
# enter the page number:12
# Reviews in page1
# 56
# Reviews in page2
# 56
# Reviews in page3
# 56
# Reviews in page4
# 56
# Reviews in page5
# 56
# Reviews in page6
# 56
# Reviews in page7
# 56
# Reviews in page8
# 56
# Reviews in page9
# 56
# Reviews in page10
# 56
# Reviews in page11
# 56
# Reviews in page12
# 56

# %%
for i in ipohoneReviews:
    print(i)
# Out:
# 4.6★1,074 Ratings &123 Reviews5★4★3★2★1★90967191168
# 4.6★
# 1,074 Ratings &
# 123 Reviews
# 5Fabulous!
# It's not pro, it's 13 pro max.I switched from 6s to 13 pro max.Ultimate performance as expected bcz A15 bionic processor is at its best.Camera is just amazing as triple camera with sensor shift motion and night vision.Video recording in night mode with cinematic mode is just cute ever.Display:-Wooww as 120Hz is just super smooth, gives you ultimate gaming experience. You will hang on but your iPhone won't. Battery is long lasting too but you may be not😉😉😜😜.Front camera is a...READ MORE
# Sonu SharmaCertified Buyer, Jodhpur7 months ago72171552PermalinkReport Abuse
# Sonu SharmaCertified Buyer, Jodhpur7 months ago
# 72171552PermalinkReport Abuse
# 5Best in the market!
# ...

# %%
import pandas as pd
data =(ipohoneReviews)
df = pd.DataFrame(data)
print(df)
# Out:
#                                                      0
# 0    4.6★1,074 Ratings &123 Reviews5★4★3★2★1★909671...
# 1                                                 4.6★
# 2                                      1,074 Ratings &
# 3                                          123 Reviews
# 4                                           5Fabulous!
# ..                                                 ...
# 667  Kaustav PramanikCertified Buyer, Kolkata13 day...
# 668  Kaustav PramanikCertified Buyer, Kolkata13 day...
# 669                            00PermalinkReport Abuse
# 670
# 671  ABOUTContact UsAbout UsCareersFlipkart Stories...
#
# [672 rows x 1 columns]

# %%
df.to_csv("Reviews.csv")
